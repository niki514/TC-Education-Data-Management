# %%
import pandas as pd

# %%
#import csv file from local storage
#this file was created by exporting a Zotero folder in csv format

df = pd.read_csv(r"C:\Users\Niki\Documents\SeniorProject.csv")
df.head()
# Out:
#         Key       Item Type  Publication Year                         Author  \
# 0  S3RRHTEX  journalArticle            1990.0                Schauble, Leona
# 1  QTI7IMTS  journalArticle            1995.0              Metz, Kathleen E.
# 2  G8TSSVCH  journalArticle            1997.0                   Kuhn, Deanna
# 3  L5SVXWJE  journalArticle            2000.0                 DeVries, Rheta
# 4  5UHEFZEJ  journalArticle               NaN  Kuo, Eric; Wallace, Tanner L.
#
#                                                Title  \
# 0  Belief Revision in Children: The Role of Prior...
# 1  Reassessment of Developmental Constraints on C...
# 2  Constraints or Guideposts? Developmental Psych...
# 3  Vygotsky, Piaget, and education: a reciprocal ...
# 4  Publishing Qualitative Research in the Journal...
#
#                           Publication Title  ISBN  ISSN  DOI  Url  ...  \
# 0  Journal of Experimental Child Psychology   NaN   NaN  NaN  NaN  ...
# ...

# %%
#columns with all null values were removed, as these were representative of variables not considered in my data collection
df = df.replace('nan', '')

df = df.dropna(axis = 'columns', how = 'all')

"""
the file attachment column was removed as it shows where files are located on my personal computer (on top of that, 
the file paths are outdated because the computer that originally contained those files is no longer in use)
"""
df.drop(columns = "File Attachments", inplace = True)
    
df.head()
# Out:
#         Key       Item Type  Publication Year                         Author  \
# 0  S3RRHTEX  journalArticle            1990.0                Schauble, Leona
# 1  QTI7IMTS  journalArticle            1995.0              Metz, Kathleen E.
# 2  G8TSSVCH  journalArticle            1997.0                   Kuhn, Deanna
# 3  L5SVXWJE  journalArticle            2000.0                 DeVries, Rheta
# 4  5UHEFZEJ  journalArticle               NaN  Kuo, Eric; Wallace, Tanner L.
#
#                                                Title  \
# 0  Belief Revision in Children: The Role of Prior...
# 1  Reassessment of Developmental Constraints on C...
# 2  Constraints or Guideposts? Developmental Psych...
# 3  Vygotsky, Piaget, and education: a reciprocal ...
# 4  Publishing Qualitative Research in the Journal...
#
#                           Publication Title  Url  \
# 0  Journal of Experimental Child Psychology  NaN
# 1            Review of Educational Research  NaN
# ...

# %%
#shows the data type of each variable
df.dtypes
# Out:
# Key                   object
# Item Type             object
# Publication Year     float64
# Author                object
# Title                 object
# Publication Title     object
# Url                   object
# Abstract Note         object
# Date                 float64
# Date Added            object
# Date Modified         object
# Pages                 object
# Issue                 object
# Volume               float64
# Number Of Volumes    float64
# Publisher             object
# Notes                 object
# Manual Tags           object
# dtype: object
